# %% [markdown]
# #DESARROLLO CODIGO DE LA API
# para despues pasarla al main.py para el uso de la API

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ingestamos el dataset

# %%
df_peliculas = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/PROYECTO INDIVIDUAL FASE 1/MLOpsReviews/peliculas_final.csv", encoding="UTF8")
df_peliculas.head(3)
# Out:
#     type                 title  \
# 0  movie   the grand seduction
# 1  movie  take care good night
# 2  movie  secrets of deception
#
#                                                 cast  date_added  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent  2021-03-30
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar  2021-03-30
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...  2021-03-30
#
#    release_year rating_x                listed_in  \
# 0          2014        g            comedy, drama
# 1          2018      13+     drama, international
# 2          2017        g  action, drama, suspense
#
#                                          description   id plataforma  \
# 0  a small fishing village must procure a local d...  as1          a
# 1  a metro family decides to fight a cyber crimin...  as2          a
# 2  after a man discovers his wife is cheating on ...  as3          a
#
#                  link_pelicula  duration_int duration_type  score
# 0  https://www.primevideo.com/           113           min    3.5
# 1  https://www.primevideo.com/           110           min    3.5
# 2  https://www.primevideo.com/            74           min    3.5

# %% [markdown]
# ###API 3
# Cantidad de películas por plataforma con filtro de PLATAFORMA. (La función debe llamarse get_count_platform(platform))

# %%
varplataforma = 'netflix'

dicc = {"netflix":"n","amazon":"a","hulu":"h","disney":"d"}

df_x = df_peliculas[(df_peliculas.plataforma == dicc[varplataforma])   &   (df_peliculas["type"] == "movie")]
y = df_x.shape[0]
    
y
# Out:
# 6131

# %%
df_x.shape
# Out:
# (6131, 14)

# %%
 df_peliculas[(df_peliculas.plataforma == dicc[varplataforma])   &   (df_peliculas["type"] == "movie")].count()
# Out:
# type             6131
# title            6131
# cast             5656
# date_added       6131
# release_year     6131
# rating_x         6131
# listed_in        6131
# description      6131
# id               6131
# plataforma       6131
# link_pelicula    6131
# duration_int     6131
# duration_type    6131
# score            6131
# dtype: int64

# %%
def get_count_platform(varplataforma):
    dicc = {"netflix":"n","amazon":"a","hulu":"h","disney":"d"}

    df_x = df_peliculas[(df_peliculas.plataforma == dicc[varplataforma])   &   (df_peliculas["type"] == "movie")]
            
    return len(df_x.index)

get_count_platform("netflix")
# Out:
# 6131

# %% [markdown]
# ###API 2
# Cantidad de películas por plataforma con un puntaje mayor a XX en determinado año (la función debe llamarse get_score_count(platform, scored, year))

# %%
varplataforma = 'amazon'
varpuntaje = 3.6
varanio = 2021

dicc = {"netflix":"n","amazon":"a","hulu":"h","disney":"d"}

df_x = df_peliculas[(df_peliculas.plataforma == dicc[varplataforma]) &  
                    (df_peliculas["type"] == "movie")    &
                    (df_peliculas["score"] > varpuntaje) &
                    (df_peliculas["release_year"] == varanio) ]
y = df_x.shape[0]
    
y
# Out:
# 12

# %%
df_x
# Out:
#        type                              title  \
# 5401  movie                      dons of disco
# 5637  movie  brightheart: let your light shine
# 5708  movie                   hampton's legion
# 5827  movie                      back for good
# 6190  movie                       aanum pennum
# 6343  movie          terror at blood fart lake
# 6346  movie                             sara's
# 7288  movie                  day of the reaper
# 7982  movie                         vivandière
# 8867  movie                  birds of paradise
# 9497  movie            lance woods: undeniable
# 9626  movie                 thalaivii (telugu)
#
#                                                    cast date_added  \
# 5401                         tom hooker, stefano zandri        NaN
# 5637   carrie jo crosby, daisy hamilton, justine huxley        NaN
# 5708  jerry chesser, jezibell anat, russell dobson, ...        NaN
# 5827  molly donovan, ian cramer, peter donovan, juli...        NaN
# 6190  samyuktha menon, joju george, indrajith, parva...        NaN
# 6343                                                NaN        NaN
# 6346          anna benn, sunny wayne, mallika sukumaran        NaN
# 7288                                                NaN        NaN
# 7982         robin black, mikyla bordner, dallan starks        NaN
# 8867  diana silvers, kristine froseth, jacqueline bi...        NaN
# 9497                                        lance woods        NaN
# 9626               kangana ranaut, arvind swamy, nassar        NaN
#
#       release_year rating_x  \
# 5401          2021      18+
# 5637          2021        g
# 5708          2021      16+
# 5827          2021      18+
# 6190          2021      13+
# 6343          2021      18+
# 6346          2021      13+
# 7288          2021      13+
# 7982          2021      16+
# 8867          2021      16+
# 9497          2021      18+
# 9626          2021      all
#
#                                               listed_in  \
# 5401                                 documentary, drama
# 5637                   animation, kids, science fiction
# 5708                                             action
# 5827                                              drama
# 6190                                              drama
# 6343                                             horror
# 6346                                      comedy, drama
# 7288                                             horror
# 7982                                              drama
# 8867                        drama, young adult audience
# 9497  arts, entertainment, and culture, comedy, spec...
# 9626                                              drama
#
#                                             description      id plataforma  \
# 5401  in the 1980s, den harrow dominated the europea...  as5402          a
# 5637  brightheart the firefly is the hero of her vil...  as5638          a
# 5708  when the confederacy can no longer finance mas...  as5709          a
# 5827  an actress confronts her quarter-life crisis b...  as5828          a
# 6190  an anthology film that takes you to different ...  as6191          a
# 6343  the legend of blood fart lake is...well...lege...  as6344          a
# 6346  "sara's" as the name indicates, is the story o...  as6347          a
# 7288  in this rare super-8mm clasher classic from ti...  as7289          a
# 7982  two young women from both sides of the civil w...  as7983          a
# 8867  kate is an aspiring ballerina who is given a s...  as8868          a
# 9497  in his first comedy special, lance woods share...  as9498          a
# 9626  thalaivi is the dramatic story of a woman who ...  as9627          a
#
#                     link_pelicula  duration_int duration_type  score
# 5401  https://www.primevideo.com/            82           min    3.7
# 5637  https://www.primevideo.com/            84           min    3.7
# 5708  https://www.primevideo.com/            81           min    3.7
# 5827  https://www.primevideo.com/            73           min    3.7
# 6190  https://www.primevideo.com/            96           min    3.7
# 6343  https://www.primevideo.com/            74           min    3.7
# 6346  https://www.primevideo.com/           118           min    3.7
# 7288  https://www.primevideo.com/            71           min    3.7
# 7982  https://www.primevideo.com/            57           min    3.7
# 8867  https://www.primevideo.com/           113           min    3.7
# 9497  https://www.primevideo.com/            59           min    3.7
# 9626  https://www.primevideo.com/           151           min    3.7

# %%
def get_score_count(varplataforma, varpuntaje, varanio):
    dicc = {"netflix":"n","amazon":"a","hulu":"h","disney":"d"}

    df_x = df_peliculas[(df_peliculas.plataforma == dicc[varplataforma]) &  
                        (df_peliculas["type"] == "movie")    &
                        (df_peliculas["score"] > varpuntaje) &
                        (df_peliculas["release_year"] == varanio) ]
            
    return len(df_x.index)
    

get_score_count("amazon", 3.6, 2021)
# Out:
# 12

# %% [markdown]
# ###API 1
# Película con mayor duración con filtros opcionales de AÑO, PLATAFORMA Y TIPO DE DURACIÓN. (la función debe llamarse get_max_duration(year, platform, duration_type))

# %%
varanio = 2021
varplataforma = 'amazon'
vartipo = 'min'


dicc = {"netflix":"n","amazon":"a","hulu":"h","disney":"d"}

df_x = df_peliculas[(df_peliculas.plataforma == dicc[varplataforma]) &  
                    (df_peliculas["type"] == "movie")    &
                    (df_peliculas["duration_type"] == vartipo) &
                    (df_peliculas["release_year"] == varanio) ]
#len(df_x.index)
df_x.duration_int.max()
# Out:
# 188

# %%
df_x[(df_peliculas["duration_int"] > 187)]
# Out:
# <ipython-input-91-6f98dca9cc45>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_x[(df_peliculas["duration_int"] > 187)]
#        type     title                                  cast date_added  \
# 8931  movie  enclosed  francis duru paul sambo bruno iwuoha        NaN
#
#       release_year rating_x       listed_in  \
# 8931          2021      16+  drama, romance
#
#                                             description      id plataforma  \
# 8931  three freinds with different phases in marriag...  as8932          a
#
#                     link_pelicula  duration_int duration_type  score
# 8931  https://www.primevideo.com/           188           min    3.5

# %%
def get_max_duration(varanio, varplataforma, vartipo):
    dicc = {"netflix":"n","amazon":"a","hulu":"h","disney":"d"}

    df_x = df_peliculas[(df_peliculas.plataforma == dicc[varplataforma]) &  
                        (df_peliculas["type"] == "movie")    &
                        (df_peliculas["duration_type"] == vartipo) &
                        (df_peliculas["release_year"] == varanio) ]

    return df_x.duration_int.max()


get_max_duration(2021, "amazon", "min")
# Out:
# 188

# %% [markdown]
# ####API 4
# Actor que más se repite según plataforma y año. (La función debe llamarse get_actor(platform, year))

# %%
varplataforma = 'disney'
varanio = 2021


dicc = {"netflix":"n","amazon":"a","hulu":"h","disney":"d"}

df_x = df_peliculas[(df_peliculas.plataforma == dicc[varplataforma]) &  
                    (df_peliculas["release_year"] == varanio) ]

df_y = df_x["cast"].str.split(',').explode().str.strip().value_counts()
df_y

#nombreactor = df_y.index[0]
#df_x.to_excel("/content/drive/MyDrive/Colab Notebooks/PROYECTO INDIVIDUAL FASE 1/MLOpsReviews/datacast.xlsx", index=False)
# Out:
# tress macneille        4
# bill farmer            4
# kaitlyn robrock        3
# yvette nicole brown    3
# jack dylan grazer      3
#                       ..
# jake green             1
# ashly burch            1
# gal gadot              1
# peter staley           1
# kat dennings           1
# Name: cast, Length: 329, dtype: int64

# %%
nombreactor = df_y.index[0]
nombreactor
# Out:
# 'tress macneille'

# %% [markdown]
# verificamos generando un excel para revisar la cantidad que se repite el actor este OK

# %% [markdown]
# ![datacast-xlsx-Hojas-de-cálculo-de-Google.png](data:image/png;base64,...)

# %%
def get_actor(varplataforma, varanio):

    dicc = {"netflix":"n","amazon":"a","hulu":"h","disney":"d"}

    df_x = df_peliculas[(df_peliculas.plataforma == dicc[varplataforma]) &  
                        (df_peliculas["release_year"] == varanio) ]

    df_y = df_x["cast"].str.split(',').explode().str.strip().value_counts()
    nombreactor = df_y.index[0]
    
    return nombreactor


get_actor("disney", 2021)
# Out:
# 'tress macneille'

# %% [markdown]
# =========
